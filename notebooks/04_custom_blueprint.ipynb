# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, KBinsDiscretizer
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import os
import joblib

from src.feature_engineering import *
from src.modeling import *

import warnings
warnings.filterwarnings("ignore")

# %%
#config
OUTPUT_PATH = "output/blueprint/"
GRID_SEARCH_RESULT_PATH = "output/grid_search/tc2_run_1/grid_search_result.csv"

# %%
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)

# %% [markdown]
# ### Read grid search result

# %%
df_gs_result = pd.read_csv(GRID_SEARCH_RESULT_PATH)
print(df_gs_result.shape)
df_gs_result.head()
# Out:
# (94, 4)
#   model_name        preprocessing  \
# 0        knn  ['outlier_removal']
# 1        knn       ['polynomial']
# 2        knn          ['binning']
# 3        knn  ['standardization']
# 4        knn              ['pca']
#
#                                          best_params       rmse
# 0  {'model__n_neighbors': 15, 'model__p': 2, 'mod...  27.262520
# 1  {'model__n_neighbors': 15, 'model__p': 2, 'mod...  27.270176
# 2  {'binning__n_bins': 10, 'model__n_neighbors': ...  27.266932
# 3  {'model__n_neighbors': 15, 'model__p': 1, 'mod...  27.291581
# 4  {'model__n_neighbors': 15, 'model__p': 1, 'mod...  27.267437

# %%
pd.set_option('display.max_colwidth', None)
df_gs_result.sort_values('rmse', ascending=True).head(10)
# Out:
#    model_name                             preprocessing  \
# 62      lasso                       ['outlier_removal']
# 39      ridge                ['outlier_removal', 'pca']
# 70      lasso                ['outlier_removal', 'pca']
# 35      ridge                                   ['pca']
# 66      lasso                                   ['pca']
# 79      lasso  ['outlier_removal', 'polynomial', 'pca']
# 48      ridge  ['outlier_removal', 'polynomial', 'pca']
# 42      ridge                     ['polynomial', 'pca']
# 73      lasso                     ['polynomial', 'pca']
# 86      lasso     ['binning', 'standardization', 'pca']
#
#                                                                                              best_params  \
# 62                                                        {'model__alpha': 0.1, 'model__max_iter': 1000}
# 39                           {'model__alpha': 0.001, 'model__solver': 'auto', 'pca__n_components': 0.85}
# 70                           {'model__alpha': 0.001, 'model__max_iter': 1000, 'pca__n_components': 0.85}
# 35                              {'model__alpha': 100, 'model__solver': 'svd', 'pca__n_components': 0.85}
# 66                           {'model__alpha': 0.001, 'model__max_iter': 1000, 'pca__n_components': 0.85}
# 79  {'model__alpha': 0.001, 'model__max_iter': 1000, 'pca__n_components': 0.85, 'polynomial__degree': 3}
# 48  {'model__alpha': 0.001, 'model__solver': 'auto', 'pca__n_components': 0.85, 'polynomial__degree': 3}
# 42  {'model__alpha': 0.001, 'model__solver': 'auto', 'pca__n_components': 0.85, 'polynomial__degree': 3}
# 73  {'model__alpha': 0.001, 'model__max_iter': 1000, 'pca__n_components': 0.85, 'polynomial__degree': 3}
# 86         {'binning__n_bins': 5, 'model__alpha': 1, 'model__max_iter': 1000, 'pca__n_components': 0.85}
#
#          rmse
# 62  26.419948
# 39  26.420203
# 70  26.420203
# 35  26.420442
# 66  26.420442
# 79  26.420466
# 48  26.420466
# 42  26.420687
# 73  26.420687
# 86  26.421642

# %% [markdown]
# ### Make custom blueprint

# %%
BLUEPRINT_NAME = "outlier_poly_pca_lasso_alpha_0_001_max_iter_1000_n_components_0_85_degree_3.joblib"

steps = []

steps.append(("outlier_removal", OutlierRemoval()))
steps.append(("polynomial", PolynomialFeatures(interaction_only=False, include_bias=False, degree=3)))
# steps.append(("binning", KBinsDiscretizer(encode="ordinal", n_bins=5)))
# steps.append(("standardization", StandardScaler()))
steps.append(("pca", PCA(n_components=0.85)))
steps.append(("model", Lasso(alpha=0.001, max_iter=1000)))
# steps.append(("model", Ridge(alpha=0.001, solver="auto")))

pipeline = Pipeline(steps=steps)

#save best estimator to output folder
joblib.dump(pipeline, os.path.join(OUTPUT_PATH, BLUEPRINT_NAME))
# Out:
# ['output/blueprint/outlier_poly_pca_lasso_alpha_0_001_max_iter_1000_n_components_0_85_degree_3.joblib']
